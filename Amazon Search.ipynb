# %%
from bs4 import BeautifulSoup
import requests
import time
import datetime
import smtplib
import string
import csv
import re
import pandas as pd

# %% [markdown]
# ### Choosing topic for amazon search

# %%
topic= 'amazon echo'

# %% [markdown]
# ### Connecting to search page

# %%
google_search = 'https://www.google.com/search?channel=fs&client=ubuntu&q='
topic =re.sub(' ', '+', topic)
url1 ="%s%s" % (google_search, topic)
headers = {'User-Agent' :"Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:92.0) Gecko/20100101 Firefox/92.0" ,"Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
url = 'https://www.amazon.es/s?k=echo+dot&ref=nb_sb_noss_2'

# %%
page = requests.get(url, headers=headers)
page.status_code,len(page.text)
# Out:
# (200, 839540)

# %%
with open('website.html', 'w') as f:
    f.write(page.text)

# %% [markdown]
# ### Getting the html content of page

# %%
page_content = BeautifulSoup(page.content, "html.parser")
page_content = BeautifulSoup(page_content.prettify(),"html.parser")
page_content
# Out:
# <!DOCTYPE html>
#
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="es-es">
# <!-- sp:feature:head-start -->
# <head>
# <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
# <meta charset="utf-8"/>
# <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %% [markdown]
# ### Getting complete information for every item showned on first page

# %%
whole_item_search = page_content.find_all('div' ,{'class' :"a-section a-spacing-none"})
print(len(whole_item_search))
print(whole_item_search[0])#complete info about first item
# Out:
# 69
# <div class="a-section a-spacing-none">
# <div class="a-section a-spacing-none a-spacing-top-small">
# <h2 class="a-size-mini a-spacing-none a-color-base s-line-clamp-2">
# <a class="a-link-normal a-text-normal" href="/echo-dot-3-generacion-altavoz-inteligente-con-alexa-tela-de-color-antracita/dp/B07PHPXHQS/ref=sr_1_1?dchild=1&amp;keywords=echo+dot&amp;qid=1633346016&amp;sr=8-1">
# <span class="a-size-base a-color-base a-text-normal">
#                     Echo Dot (3.ª generación) - Altavoz inteligente con Alexa, tela de color antracita
#                    </span>
# </a>
# </h2>
# </div>
# <div class="a-section a-spacing-none a-spacing-top-micro">
# <div class="a-row a-size-small">
# <span aria-label="4,7 de 5 estrellas">
# ...

# %%
#getting link for the first item in search
links = page_content.find_all('a' ,{'class' :"a-link-normal a-text-normal"})
links[0]
# Out:
# <a class="a-link-normal a-text-normal" href="/echo-dot-3-generacion-altavoz-inteligente-con-alexa-tela-de-color-antracita/dp/B07PHPXHQS/ref=sr_1_1?dchild=1&amp;keywords=echo+dot&amp;qid=1633346016&amp;sr=8-1">
# <span class="a-size-base a-color-base a-text-normal">
#                     Echo Dot (3.ª generación) - Altavoz inteligente con Alexa, tela de color antracita
#                    </span>
# </a>

# %%
for i in range(len(links)):
    links[i]= links[i].get("href")

# %%
links[0] , len(links)
# Out:
# ('/echo-dot-3-generacion-altavoz-inteligente-con-alexa-tela-de-color-antracita/dp/B07PHPXHQS/ref=sr_1_1?dchild=1&keywords=echo+dot&qid=1633346016&sr=8-1',
#  60)

# %%
description = page_content.find_all('span' ,{'class' :"a-size-base a-color-base a-text-normal"})
description
# Out:
# [<span class="a-size-base a-color-base a-text-normal">
#                      Echo Dot (3.ª generación) - Altavoz inteligente con Alexa, tela de color antracita
#                     </span>,
#  <span class="a-size-base a-color-base a-text-normal">
#                      Echo Dot (4.ª generación) | Altavoz inteligente con Alexa | Antracita
#                     </span>,
#  <span class="a-size-base a-color-base a-text-normal">
#                      Echo Dot (4.ª generación) | Altavoz inteligente con reloj y Alexa | Azul grisáceo
#                     </span>,
#  <span class="a-size-base a-color-base a-text-normal">
#                      Echo (4.ª generación) | Sonido de alta calidad | Blanco + TP-Link Tapo Bombilla Inteligente (E27), compatible con Alexa
#                     </span>,
#  <span class="a-size-base a-color-base a-text-normal">
#                      Echo Dot (3.ª generación), Tela de color antracita + TP-Link Tapo Bombilla Inteligente (E27), compatible con Alexa
# ...

# %%
for i in range(len(description)):
    description[i]= description[i].text.strip()

# %%
for i in range(len(description)):
    description[i]= description[i].replace(',', '.')

# %%
description[0] , len(description)
# Out:
# ('Echo Dot (3.ª generación) - Altavoz inteligente con Alexa. tela de color antracita',
#  60)

# %%
price= page_content.find_all('span' ,{'class' :"a-price-whole"})

# %%
for i in range(len(price)):
    price[i]= price[i].text.strip()

# %%
for i in range(len(price)):
    price[i]= price[i].replace(',', '.')

# %%
price[0], len(price)
# Out:
# ('34.99', 59)

# %%
reviews= page_content.find_all('span' ,{'class' :"a-icon-alt"})

# %%
for i in range(len(reviews)): 
    reviews[i]= reviews[i].text.strip()

# %%
for i in range(len(price)):    
    reviews[i]= reviews[i].replace(',', '.')
    reviews[i]= reviews[i][:3]

# %%
reviews[0], len(reviews)
# Out:
# ('4.7', 62)

# %%
#printing the first 10 products to cvs
description[i] + ',' +  price[i] + ',' + reviews[i]
# Out:
# 'EZVIZ Cámara de Vigilancia Interior IP Cámara WiFi de Seguridad de Visión Nocturna Audio Bidireccional. Compatible con Alexa y Google. Andriod/iOS CTQ2C 720P (Blanco),38.99,4 E'

# %%
amazon = [' '] * 100

# %%
for i in range(10):
    amazon[i]=  description[i] + ',' + price[i] + ',' + reviews[i]

# %%
amazon[1]
# Out:
# 'Echo Dot (4.ª generación) | Altavoz inteligente con Alexa | Antracita,44.99,4.6'

# %%
header=['Title', 'Price', 'Reviews']

# %%
with open('amazon_echo.csv','w', newline= '', encoding='UTF8') as f:
    writer= csv.writer(f)
    writer.writerow(header)
    for i in range(10):
        writer.writerow([description[i] , price[i] , reviews[i]])

# %%
df = pd.read_csv(r'amazon_echo.csv')

# %%
df
# Out:
#                                                Title   Price  Reviews
# 0  Echo Dot (3.ª generación) - Altavoz inteligent...   34.99      4.7
# 1  Echo Dot (4.ª generación) | Altavoz inteligent...   44.99      4.6
# 2  Echo Dot (4.ª generación) | Altavoz inteligent...   69.99      4.6
# 3  Echo (4.ª generación) | Sonido de alta calidad...   79.99      4.6
# 4  Echo Dot (3.ª generación). Tela de color antra...   43.97      4.6
# 5  Nuevo Echo Dot (4.ª generación). versión inter...   59.99      4.7
# 6  Echo Dot (4.ª generación). Reacondicionado cer...   53.99      3.9
# 7  Echo Studio - Altavoz inteligente con sonido d...  199.99      4.4
# 8  Echo Dot (3.ª generación) Reacondicionado Cert...   44.99      4.6
# 9  Nuevo Echo Show 5 (2.ª generación. modelo de 2...   64.99      4.5
